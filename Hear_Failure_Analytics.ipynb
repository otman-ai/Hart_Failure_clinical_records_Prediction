# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
df = df.drop(['time','serum_sodium','ejection_fraction','platelets'],axis=1)
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  high_blood_pressure  \
# 0  75.0        0                       582         0                    1
# 1  55.0        0                      7861         0                    0
# 2  65.0        0                       146         0                    0
# 3  50.0        1                       111         0                    0
# 4  65.0        1                       160         1                    0
#
#    serum_creatinine  sex  smoking  DEATH_EVENT
# 0               1.9    1        0            1
# 1               1.1    1        0            1
# 2               1.3    1        1            1
# 3               1.9    1        0            1
# 4               2.7    0        0            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   high_blood_pressure       299 non-null    int64
#  5   serum_creatinine          299 non-null    float64
#  6   sex                       299 non-null    int64
#  7   smoking                   299 non-null    int64
#  8   DEATH_EVENT               299 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 21.1 KB

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# high_blood_pressure         0
# serum_creatinine            0
# sex                         0
# smoking                     0
# DEATH_EVENT                 0
# dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df['age'].plot(figsize=(17,9))
# Out:
# <AxesSubplot:>

# %%
df['DEATH_EVENT'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
df.loc[df['DEATH_EVENT'] == 1,['sex']].value_counts().plot(kind='bar',figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
df.loc[df['DEATH_EVENT']==0,'sex'].value_counts().plot(kind='bar',figsize=(17,8))
# Out:
# <AxesSubplot:>

# %%
df['diabetes'].value_counts().plot(kind='pie',figsize=(15,8))
# Out:
# <AxesSubplot:ylabel='diabetes'>

# %%
df.loc[df['DEATH_EVENT'] == 1,'age'].plot(figsize=(15,9))
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
df['age'].describe()
# Out:
# count    299.000000
# mean      60.833893
# std       11.894809
# min       40.000000
# 25%       51.000000
# 50%       60.000000
# 75%       70.000000
# max       95.000000
# Name: age, dtype: float64

# %%
df.loc[df['anaemia'] == 1,'age'].min()
# Out:
# 40.0

# %%
df.loc[df['anaemia'] == 1,'age'].max()
# Out:
# 95.0

# %%
df.loc[df['anaemia'] == 0,'age'].max()
# Out:
# 94.0

# %%
df.loc[df['anaemia'] == 0,'age'].min()
# Out:
# 40.0

# %%
df[['smoking','DEATH_EVENT']].value_counts().plot(kind='pie',figsize=(14,9))
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.loc[df['smoking']==0,'DEATH_EVENT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['creatinine_phosphokinase'].max()
# Out:
# 7861

# %%
df['serum_creatinine'].max()
# Out:
# 9.4

# %%
from sklearn.linear_model import LogisticRegression

# %%
LogisticRegression?

# %%
df[['age','DEATH_EVENT']].plot()
# Out:
# <AxesSubplot:>
